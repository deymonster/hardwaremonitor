# %%
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[2], line 3
#       1 from crud.company import company_crud
#       2 from crud.license import license_crud
# ----> 3 from core.db import get_db_session
#
# File ~/My projects/hardwaremonitor/backend/core/db.py:7
#       4 from sqlalchemy import NullPool
#       5 from sqlalchemy.ext.asyncio import AsyncSession, async_sessionmaker, create_async_engine
# ----> 7 from config import settings
#      10 def pydantic_serializer(value):
#      11     json_method = getattr(value, "model_dump_json", None)
#
# File ~/My projects/hardwaremonitor/backend/config.py:63
#      48     @computed_field
#      49     @property
#      50     def DB_ASYNC_CONNECTION_STR(self) -> str:
#      51         return str(
#      52             PostgresDsn.build(  # type: ignore
#      53                 scheme="postgresql+asyncpg",
#    (...)
# ...
